# %% [markdown]
# <a href="https://colab.research.google.com/github/sreesreevallichowdary-png/Data_Table-/blob/main/Firstname_Lastname_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Task 1: Load dataset and inspect rows
import pandas as pd
# Step 1: Use the file ID from the Google Drive link
file_id = "1Mlu9r3afSGz5_02Y3wDJoQLpXszQXaIU"  # extracted from your link

# Step 2: Construct the proper download URL
download_url = f"https://drive.google.com/uc?id={file_id}"

# Step 3: Load the CSV with pandas
df = pd.read_csv(download_url,index_col="order_id",encoding="utf-8")

# Step 4: Inspect the data
#print(df.head())
#print(df.tail())
# Load CSV, set order_id as index
#df = pd.read_csv("orders.csv", index_col="order_id")

# Display first 5 and last 5 rows
print("First 5 rows:")
print(df.head())

print("\nLast 5 rows:")
print(df.tail())

# Task 2: Structural inspection
print("\nStructural inspection:")
df_info = df.info()

# From df.info() you can answer:
# - Number of rows and columns: df.shape
print("\nRows and columns:", df.shape)

# - Missing values per column
print("\nMissing values per column:")
print(df.isnull().sum())

# - Columns needing type conversion (dates)
print("\nData types:")
print(df.dtypes)
# For date conversion:
# df['order_date'] = pd.to_datetime(df['order_date'])

# Task 3: Statistical summary
print("\nStatistical summary of numeric columns:")
print(df.describe())

# Median unit_price
median_price = df['unit_price'].median()
print("\nMedian unit_price:", median_price)

# Skewness check: compare mean vs median
mean_price = df['unit_price'].mean()
print("Mean unit_price:", mean_price)

if mean_price > median_price:
    print("unit_price appears right-skewed (mean > median).")
else:
    print("unit_price appears left-skewed or symmetric.")
# Out:
# First 5 rows:
#           customer_name   product  quantity  unit_price  order_date     status
# order_id
# 1001      Alice Johnson    Laptop       1.0     85000.0  2024-01-15  delivered
# 1002          Bob Smith     Mouse       3.0       499.0  2024-01-16    pending
# 1003        Carol White   Monitor       2.0     15000.0         NaN  delivered
# 1004         Dave Brown  Keyboard       NaN      1200.0  2024-01-18  cancelled
# 1005          Eva Green    Laptop       1.0     85000.0  2024-01-19  delivered
#
# Last 5 rows:
#          customer_name   product  quantity  unit_price  order_date     status
# order_id
# 1016       Paul Harris     Mouse       6.0       499.0  2024-01-30    pending
# 1017      Quinn Martin   Monitor       NaN     14500.0  2024-01-31  delivered
# 1018       Rachel King    Laptop       1.0     85000.0         NaN  delivered
# 1019        Sam Wright  Keyboard       3.0      1200.0  2024-02-01  cancelled
# ...
